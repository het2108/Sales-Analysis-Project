# %%
# !pip install googlesearch-python beautifulsoup4
# Out:
# Requirement already satisfied: googlesearch-python in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (4.13.3)
# Requirement already satisfied: requests>=2.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->googlesearch-python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->googlesearch-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->googlesearch-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->googlesearch-python) (2025.1.31)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from googlesearch import search
from urllib.parse import urlparse

# %%
# Keywords for a B2B model
keywords = [
    "digital marketing agency India",
    "SEO service India",
    "web design agency India"
]

# Will store all related url's in set
urls = set()
for keyword in keywords:
    for result in search(keyword, num_results=15):  # Top 15 results per keyword
        urls.add(result)

# Convert to DataFrame and show sample
df = pd.DataFrame(urls, columns=["Website URL"])
print(df.head())

df.to_excel("agency_websites.xlsx", index=False)
# Out:
#                                          Website URL
# 0                  https://www.whiteriversmedia.com/
# 1                    https://www.mandywebdesign.com/
# 2                         https://www.brandloom.com/
# 3                         https://www.digidarts.com/
# 4  https://www.ezrankings.com/seo-company-india.html

# %%
df.shape
# Out:
# (45, 1)

# %%
def extract_company_info(url):
    try:
        def extract_domain_name(url):
                if urlparse(url).netloc.split('.')[0].capitalize()=='Www':
                    return urlparse(url).netloc.split('.')[1].capitalize()
                return urlparse(url).netloc.split('.')[0].capitalize()
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        text = soup.get_text()
        company=extract_domain_name(url)
        def extract_location(soup):
                location = "N/A"
            
                # Define more comprehensive keywords for detection
                keywords = ["india", "delhi", "mumbai", "bangalore", "pune", "kolkata", "hyderabad", 
                            "chennai", "noida", "gurgaon", "address", "location", "contact us"]
            
                # Collect all potential address-containing tags
                potential_tags = soup.find_all(["footer", "address", "p", "div", "span"], 
                                               string=lambda text: text and any(k in text.lower() for k in keywords))
            
                for tag in potential_tags:
                    text = tag.get_text(separator=" ", strip=True)
                    # Simple heuristic to check if it's an address-like text
                    if len(text) > 15 and any(word in text.lower() for word in keywords):
                        # Optional: Filter out noisy lines like phone numbers or email-only text
                        if not re.search(r"(blocked|sorry|copyright)", text.lower()):
                            location = text
                            break
            
                return location
        def extract_contact_person(text):
                # Common patterns around names
                patterns = [
                    r"(Founder|CEO|Co-Founder|Director|Head|Manager)[^a-zA-Z]+([A-Z][a-z]+ [A-Z][a-z]+)",  # e.g. Founder John Doe
                    r"([A-Z][a-z]+ [A-Z][a-z]+)[^\n]{0,50}(Founder|CEO|Director)",  # e.g. John Doe - CEO
                    r"Name[:\-]\s*([A-Z][a-z]+(?: [A-Z][a-z]+)?)",  # Name: John Doe
                ]
            
                for pattern in patterns:
                    match = re.search(pattern, text)
                    if match:
                        return match.group(0).strip()
            
                return "N/A"
        # Extract email addresses
        emails = re.findall(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", text)
        email = emails[0] if emails else "N/A"

        # Extract phone numbers (Indian format or general format)
        phones = re.findall(r"(\+91[\-\s]?\d{10}|\d{3,5}[\-\s]?\d{6,8})", text)
        phone = phones[0] if phones else "N/A"

        # Try to get location/address from footer or text
        location=extract_location(soup)

        # Try to find a contact person like CEO, Founder, etc.
        
        contact_person=extract_contact_person(text)

        # Assume industry from context — since we're targeting B2B services
        industry = "Digital Marketing / Web Agency"

        return {
            "Company Name": company,
            "Contact Person": contact_person,
            "Industry": industry,
            "Website": url,
            "Email": email,
            "Phone": phone,
            "Location": location
        }

    except Exception as e:
        return {
            "Company Name": "N/A",
            "Contact Person": "N/A",
            "Industry": "N/A",
            "Website": url,
            "Email": "N/A",
            "Phone": "N/A",
            "Location": "N/A",
        }

# Extract info for each company
data = [extract_company_info(url) for url in urls]
df_companyInfo = pd.DataFrame(data)

# Show sample output

# %%
df_companyInfo.to_excel("agency_detailed_info.xlsx", index=False)

# %%
df_companyInfo
# Out:
#               Company Name                                     Contact Person  \
# 0                    Vocso                                                N/A
# 1   Seoexpertscompanyindia                               CEO, Friction Studio
# 2                    Foduu                             Manager – Znergy Cable
# 3          Mumbaiwebdesign                               Director\n\nGood Day
# 4                Brandloom                            Director Ashley Stewart
# 5               The7eagles                                                N/A
# 6              Webeesocial                             Manager, Teamwork Arts
# 7          Indiawebdesigns                                                N/A
# 8         Wefttechnologies                                                N/A
# 9              Idigitalise  Blog News Testimonials   ABOUT  About iDigital...
# 10              Ezrankings                                                N/A
# 11               Noviindus                                                N/A
# 12            Rankingbyseo                                                N/A
# 13           Aaravinfotech                                                N/A
# 14                     N/A                                                N/A
# 15          Aoneseoservice                                                N/A
# 16                Socialee                                                N/A
# 17                 Matebiz                                                N/A
# 18             Socialpanga                                                N/A
# 19               Digidarts                        Mukund Rao Muvin Co-Founder
# 20             Techmagnate                                  CEO Sarvesh Bagla
# 21            Neelnetworks                                                N/A
# 22              Ezrankings                                                N/A
# 23          Mandywebdesign                                                N/A
# 24       Seoserviceinindia                          Blog Commenting, Director
# 25            Orangemantra                                                N/A
# 26              Designrush                                                N/A
# 27              Omrdigital                                                N/A
# 28                  Acodez                                                N/A
# 29                 Matebiz                                                N/A
# 30                Linkedin                                                N/A
# 31                Thatware                                                N/A
# 32                Pwskills                                                N/A
# 33      Rankontechnologies                                                N/A
# 34            Seodiscovery                       Directory Listings: Director
# 35                Seotonic                         Manager, Digital Marketing
# 36               Webhopers  Great Work Environment and Learning Experience...
# 37              Designrush                                                N/A
# 38               Webhopers  Great Work Environment and Learning Experience...
# 39              Ezrankings                                                N/A
# 40            Colorwhistle                                                N/A
# 41                Linkedin                           CEO | 22 Years Expertise
# 42                 Semrush                                                N/A
# 43              Designrush                                                N/A
#
#                           Industry  \
# 0   Digital Marketing / Web Agency
# 1   Digital Marketing / Web Agency
# 2   Digital Marketing / Web Agency
# 3   Digital Marketing / Web Agency
# 4   Digital Marketing / Web Agency
# 5   Digital Marketing / Web Agency
# 6   Digital Marketing / Web Agency
# 7   Digital Marketing / Web Agency
# 8   Digital Marketing / Web Agency
# 9   Digital Marketing / Web Agency
# 10  Digital Marketing / Web Agency
# 11  Digital Marketing / Web Agency
# 12  Digital Marketing / Web Agency
# 13  Digital Marketing / Web Agency
# 14                             N/A
# 15  Digital Marketing / Web Agency
# 16  Digital Marketing / Web Agency
# 17  Digital Marketing / Web Agency
# 18  Digital Marketing / Web Agency
# 19  Digital Marketing / Web Agency
# 20  Digital Marketing / Web Agency
# 21  Digital Marketing / Web Agency
# 22  Digital Marketing / Web Agency
# 23  Digital Marketing / Web Agency
# 24  Digital Marketing / Web Agency
# 25  Digital Marketing / Web Agency
# 26  Digital Marketing / Web Agency
# 27  Digital Marketing / Web Agency
# 28  Digital Marketing / Web Agency
# 29  Digital Marketing / Web Agency
# 30  Digital Marketing / Web Agency
# 31  Digital Marketing / Web Agency
# 32  Digital Marketing / Web Agency
# 33  Digital Marketing / Web Agency
# 34  Digital Marketing / Web Agency
# 35  Digital Marketing / Web Agency
# 36  Digital Marketing / Web Agency
# 37  Digital Marketing / Web Agency
# 38  Digital Marketing / Web Agency
# 39  Digital Marketing / Web Agency
# 40  Digital Marketing / Web Agency
# 41  Digital Marketing / Web Agency
# 42  Digital Marketing / Web Agency
# 43  Digital Marketing / Web Agency
#
#                                               Website  \
# 0                              https://www.vocso.com/
# 1                 https://seoexpertscompanyindia.com/
# 2                              https://www.foduu.com/
# 3                     https://www.mumbaiwebdesign.in/
# 4                          https://www.brandloom.com/
# 5           https://the7eagles.com/india/seo-company/
# 6                            https://webeesocial.com/
# 7                         https://indiawebdesigns.in/
# 8   https://wefttechnologies.com/digital-marketing...
# 9                            https://idigitalise.net/
# 10                        https://www.ezrankings.com/
# 11  https://noviindus.com/web-designing-company-in...
# 12                      https://www.rankingbyseo.com/
# 13  https://www.aaravinfotech.com/web-design-servi...
# 14                                     /search?num=17
# 15                    https://www.aoneseoservice.com/
# 16                           https://www.socialee.in/
# 17  https://www.matebiz.com/digital-marketing-serv...
# 18                           https://socialpanga.com/
# 19                         https://www.digidarts.com/
# 20                       https://www.techmagnate.com/
# 21                      https://www.neelnetworks.com/
# 22  https://www.ezrankings.com/seo-company-india.html
# 23                    https://www.mandywebdesign.com/
# 24                   https://seoserviceinindia.co.in/
# 25  https://www.orangemantra.com/services/search-e...
# 26  https://www.designrush.com/agency/digital-agen...
# 27                            https://omrdigital.com/
# 28                                 https://acodez.in/
# 29                           https://www.matebiz.com/
# 30  https://www.linkedin.com/pulse/top-web-design-...
# 31             https://thatware.co/seo-company-india/
# 32  https://pwskills.com/blog/digital-marketing-co...
# 33   https://www.rankontechnologies.com/seo-services/
# 34  https://www.seodiscovery.com/seo-company-india...
# 35                          https://www.seotonic.com/
# 36        https://www.webhopers.com/seo-company-india
# 37  https://www.designrush.com/agency/website-desi...
# 38  https://www.webhopers.com/top-web-designing-co...
# 39  https://www.ezrankings.com/web-design-company-...
# 40                          https://colorwhistle.com/
# 41  https://www.linkedin.com/pulse/top-10-digital-...
# 42   https://www.semrush.com/agencies/list/seo/india/
# 43  https://www.designrush.com/agency/search-engin...
#
#                               Email           Phone  \
# 0                               N/A             N/A
# 1   info@seoexpertscompanyindia.com             N/A
# 2                    info@foduu.com             N/A
# 3          sales@mumbaiwebdesign.in  +91 9967857485
# 4                care@brandloom.com  +91-7669647020
# 5                               N/A   +919042275793
# 6     soumya.sharma@webeesocial.com             N/A
# 7                               N/A             N/A
# 8                               N/A             N/A
# 9             ihelp@idigitalise.net    355694095558
# 10         contactus@ezrankings.com  +91-9560133711
# 11                crm@noviindus.com  +91 9995843985
# 12           sales@rankingbyseo.com   +919953532683
# 13            biz@aaravinfotech.com   +912250245291
# 14                              N/A             N/A
# 15          info@aoneseoservice.com  +91 8101118111
# 16                              N/A             N/A
# 17                              N/A             N/A
# 18                              N/A             N/A
# 19             gameon@digidarts.com      8929447313
# 20          enquiry@techmagnate.com  +91-9910308266
# 21           admin@neelnetworks.com             N/A
# 22         contactus@ezrankings.com  +91-9560133711
# 23                              N/A     9872-774871
# 24                              N/A   +919717686168
# 25                              N/A  +91-9870289050
# 26                              N/A             N/A
# 27                              N/A             N/A
# 28                   info@acodez.in             N/A
# 29                              N/A             N/A
# 30                              N/A             N/A
# 31                 info@thatware.co  +91-7044080698
# 32             support@pwskills.com  +91 8448982581
# 33   support@rankontechnologies.com             N/A
# 34                              N/A             N/A
# 35                              N/A   +919893390926
# 36  +916000810002info@webhopers.com   +916000810002
# 37                              N/A             N/A
# 38  +916000810002info@webhopers.com   +916000810002
# 39         contactus@ezrankings.com  +91-9560133711
# 40                              N/A             N/A
# 41                              N/A             N/A
# 42                              N/A             N/A
# 43                              N/A             N/A
#
#                                              Location
# 0   At Vertelo we’re helping to redefine transport...
# 1   “Since onboarding the SEO Experts Company Indi...
# 2   FODUU (Foundation Of Design Uprising Unit) is ...
# 3                                   Mumbai Web Design
# 4   Take advantage of our expertise. Build your Br...
# 5   As the internet is available in every street a...
# 6   WeBeeSocial is a full-scale Digital Marketing ...
# 7   India's Most Trusted Web Design & Digital Mark...
# 8                                                 N/A
# 9   Get Google's #1 ranking with iDigitalize's SEO...
# 10  Our experts are here to help you with advice a...
# 11             PREMIER WEB DESIGNING COMPANY IN INDIA
# 12  This is to recommend Ranking By SEO India as a...
# 13  There is no one definitive answer to this ques...
# 14                                                N/A
# 15  As an eminent SEO company in India, we strateg...
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19  At Digidarts, we want to emphasize that we do ...
# 20  Techmagnate is India’s top digital marketing a...
# 21  Neel Networks is a trusted web design and deve...
# 22                               SEO Company in India
# 23  We are functioning as the best web development...
# 24  Search engine optimisation is the process of i...
# 25  As the forerunners in the field of SEO marketi...
# 26                                                N/A
# 27                                                N/A
# 28  Acodez is a multi-international award winning ...
# 29                                                N/A
# 30  India, with its vibrant and thriving web desig...
# 31                 Best SEO Services Company in India
# 32  Digital marketing companies or firms provide s...
# 33                  Award Winning SEO Agency in India
# 34  SEO is in our DNA. Over the last 22 years, we ...
# 35  Top SEO Agency Based in India for USA, UK, Sin...
# 36                               SEO Company in India
# 37                                                N/A
# 38            Top 10 Web Designing Companies in India
# 39                   Website Designing Services India
# 40                    Digital Web Design Agency India
# 41  Let's jump into the list of India's top 10 dig...
# 42       Put location aside and browse all  agencies.
# 43                                                N/A

# %%
# Step 1: Drop rows missing both Email and Phone
df_cleaned = df_companyInfo[~((df_companyInfo["Email"] == "N/A") & (df_companyInfo["Phone"] == "N/A"))]


# Step 2: Filter out rows where Industry is not relevant (safety check)
relevant_industries = ["digital marketing", "web agency", "web design", "seo", "development"]
df_cleaned = df_cleaned[df_cleaned["Industry"].str.lower().str.contains("|".join(relevant_industries), na=False)]

# Step 3: Drop rows where Website is missing or invalid (e.g., search links)
df_cleaned = df_cleaned[~df_cleaned["Website"].astype(str).str.contains("/search|linkedin|pulse", case=False, na=False)]

# Step 4: Strip whitespace and newlines from Contact Person and Location
df_cleaned["Contact Person"] = df_cleaned["Contact Person"].astype(str).str.replace(r"\s+", " ", regex=True).str.strip()
df_cleaned["Location"] = df_cleaned["Location"].astype(str).str.replace(r"\s+", " ", regex=True).str.strip()

# Show final cleaned dataframe and how many rows remain
df_cleaned.reset_index(drop=True, inplace=True)
df_cleaned.shape, df_cleaned.head()
# Out:
# ((26, 7),
#               Company Name           Contact Person  \
#  0  Seoexpertscompanyindia     CEO, Friction Studio
#  1                   Foduu   Manager – Znergy Cable
#  2         Mumbaiwebdesign        Director Good Day
#  3               Brandloom  Director Ashley Stewart
#  4              The7eagles                      N/A
#
#                           Industry                                    Website  \
#  0  Digital Marketing / Web Agency        https://seoexpertscompanyindia.com/
#  1  Digital Marketing / Web Agency                     https://www.foduu.com/
#  2  Digital Marketing / Web Agency            https://www.mumbaiwebdesign.in/
#  3  Digital Marketing / Web Agency                 https://www.brandloom.com/
#  4  Digital Marketing / Web Agency  https://the7eagles.com/india/seo-company/
#
#                               Email           Phone  \
#  0  info@seoexpertscompanyindia.com             N/A
#  1                   info@foduu.com             N/A
#  2         sales@mumbaiwebdesign.in  +91 9967857485
#  3               care@brandloom.com  +91-7669647020
#  4                              N/A   +919042275793
#
#                                              Location
#  0  “Since onboarding the SEO Experts Company Indi...
#  1  FODUU (Foundation Of Design Uprising Unit) is ...
#  2                                  Mumbai Web Design
#  3  Take advantage of our expertise. Build your Br...
#  4  As the internet is available in every street a...  )

# %%
df_cleaned.head(10)
# Out:
#              Company Name                                     Contact Person  \
# 0  Seoexpertscompanyindia                               CEO, Friction Studio
# 1                   Foduu                             Manager – Znergy Cable
# 2         Mumbaiwebdesign                                  Director Good Day
# 3               Brandloom                            Director Ashley Stewart
# 4              The7eagles                                                N/A
# 5             Webeesocial                             Manager, Teamwork Arts
# 6             Idigitalise  Blog News Testimonials ABOUT About iDigitalise...
# 7              Ezrankings                                                N/A
# 8               Noviindus                                                N/A
# 9            Rankingbyseo                                                N/A
#
#                          Industry  \
# 0  Digital Marketing / Web Agency
# 1  Digital Marketing / Web Agency
# 2  Digital Marketing / Web Agency
# 3  Digital Marketing / Web Agency
# 4  Digital Marketing / Web Agency
# 5  Digital Marketing / Web Agency
# 6  Digital Marketing / Web Agency
# 7  Digital Marketing / Web Agency
# 8  Digital Marketing / Web Agency
# 9  Digital Marketing / Web Agency
#
#                                              Website  \
# 0                https://seoexpertscompanyindia.com/
# 1                             https://www.foduu.com/
# 2                    https://www.mumbaiwebdesign.in/
# 3                         https://www.brandloom.com/
# 4          https://the7eagles.com/india/seo-company/
# 5                           https://webeesocial.com/
# 6                           https://idigitalise.net/
# 7                        https://www.ezrankings.com/
# 8  https://noviindus.com/web-designing-company-in...
# 9                      https://www.rankingbyseo.com/
#
#                              Email           Phone  \
# 0  info@seoexpertscompanyindia.com             N/A
# 1                   info@foduu.com             N/A
# 2         sales@mumbaiwebdesign.in  +91 9967857485
# 3               care@brandloom.com  +91-7669647020
# 4                              N/A   +919042275793
# 5    soumya.sharma@webeesocial.com             N/A
# 6            ihelp@idigitalise.net    355694095558
# 7         contactus@ezrankings.com  +91-9560133711
# 8                crm@noviindus.com  +91 9995843985
# 9           sales@rankingbyseo.com   +919953532683
#
#                                             Location
# 0  “Since onboarding the SEO Experts Company Indi...
# 1  FODUU (Foundation Of Design Uprising Unit) is ...
# 2                                  Mumbai Web Design
# 3  Take advantage of our expertise. Build your Br...
# 4  As the internet is available in every street a...
# 5  WeBeeSocial is a full-scale Digital Marketing ...
# 6  Get Google's #1 ranking with iDigitalize's SEO...
# 7  Our experts are here to help you with advice a...
# 8             PREMIER WEB DESIGNING COMPANY IN INDIA
# 9  This is to recommend Ranking By SEO India as a...

# %%
df_cleaned.to_excel("cleaned_agency_list.xlsx", index=False)
